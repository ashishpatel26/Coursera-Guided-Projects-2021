# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Create Classifiers

# %%
face_classifier= cv2.CascadeClassifier(cv2.data.haarcascades + "Haarcascades/haarcascade_frontalface_default.xml")
eye_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + "Haarcascades/haarcascade_eye.xml")

# %% [markdown]
# ### Open Image

# %%
img= cv2.imread('Images/pccw1.jpg')

# %% [markdown]
# ### Fix Image

# %%
fix_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Face Classifier

# %%
faces=face_classifier.detectMultiScale(fix_img,1.3,5)

# %% [markdown]
# ### If No Face Detected

# %%
if faces is ():
    print('No faces found')
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-7-e3f3a47a50bb>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
def detect_faces_eyes(fix_img):
    face_rects=face_classifier.detectMultiScale(fix_img)
    for(x,y,w,h) in face_rects:
        cv2.rectangle(fix_img,
                     (x,y),
                     (x+w,y+h),
                     (255,0,0),
                     7)
    eye_rects=eye_classifier.detectMultiScale(fix_img)
    for (ix,iy,iw,ih) in eye_rects:
        cv2.rectangle(fix_img,
                     (ix,iy),
                     (ix+iw,iy+ih),
                     (255,255,255),
                     5)
    return fix_img

# %%
result=detect_faces_eyes(fix_img)
plt.imshow(result)
