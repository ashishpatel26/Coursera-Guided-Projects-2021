# %% [markdown]
# # TASK #1: PROJECT OVERVIEW

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #2: MOUNT DRIVE AND IMPORT LIBRARIES/DATASETS

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
# Out:
# (34799, 32, 32, 3)

# %%
# Out:
# (34799,)

# %% [markdown]
# # TASK #3: PERFROM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 21

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 15 x 15 matrix into 225 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
# create evenly spaces variables 

    # Select a random number
    
    # read and display an image with the selected index

# %% [markdown]
# # TASK #4: CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
# Out:
# (34799, 32, 32, 1)

# %%
# Out:
# (12630, 32, 32, 1)

# %%
# Out:
# array([[[[-0.01302083],
#          [-0.02864583],
#          [-0.03125   ],
#          ...,
#          [ 0.359375  ],
#          [ 0.27604167],
#          [ 0.11979167]],
#
#         [[ 0.0234375 ],
#          [-0.00260417],
#          [-0.0390625 ],
#          ...,
#          [ 0.26041667],
#          [ 0.19010417],
#          [ 0.06770833]],
#
#         [[ 0.03125   ],
#          [-0.0078125 ],
#          [-0.0390625 ],
#          ...,
#          [ 0.12239583],
#          [ 0.08072917],
#          [ 0.01041667]],
#
#         ...,
#
#         [[-0.02864583],
#          [ 0.02604167],
#          [ 0.10416667],
#          ...,
#          [-0.65885417],
#          [-0.65364583],
#          [-0.63802083]],
#
#         [[ 0.09114583],
#          [ 0.09375   ],
#          [ 0.14583333],
#          ...,
#          [-0.8046875 ],
#          [-0.796875  ],
#          [-0.7890625 ]],
#
#         [[ 0.04947917],
#          [ 0.13020833],
#          [ 0.203125  ],
#          ...,
#          [-0.78645833],
#          [-0.78125   ],
#          [-0.77604167]]],
#
#
#        [[[-0.59114583],
#          [-0.64322917],
#          [-0.6640625 ],
#          ...,
#          [-0.515625  ],
#          [-0.42708333],
#          [-0.44270833]],
#
#         [[-0.6171875 ],
#          [-0.65104167],
#          [-0.66666667],
#          ...,
#          [-0.56770833],
#          [-0.5       ],
#          [-0.52864583]],
#
#         [[-0.6640625 ],
#          [-0.67447917],
#          [-0.69270833],
#          ...,
#          [-0.5078125 ],
#          [-0.46875   ],
#          [-0.48958333]],
#
#         ...,
#
#         [[-0.6953125 ],
#          [-0.66666667],
#          [-0.52864583],
#          ...,
#          [-0.63541667],
#          [-0.58854167],
#          [-0.62760417]],
#
#         [[-0.65104167],
#          [-0.67708333],
#          [-0.63802083],
#          ...,
#          [-0.60416667],
#          [-0.59635417],
#          [-0.62239583]],
#
#         [[-0.68229167],
#          [-0.6484375 ],
#          [-0.70833333],
#          ...,
#          [-0.66666667],
#          [-0.62239583],
#          [-0.5703125 ]]],
#
#
#        [[[-0.79427083],
#          [-0.72916667],
#          [-0.6953125 ],
#          ...,
#          [-0.6796875 ],
#          [-0.67708333],
#          [-0.66666667]],
#
#         [[-0.77604167],
#          [-0.69791667],
#          [-0.66145833],
#          ...,
#          [-0.69270833],
#          [-0.69791667],
#          [-0.68229167]],
#
#         [[-0.75      ],
#          [-0.65885417],
#          [-0.66666667],
#          ...,
#          [-0.6796875 ],
#          [-0.67447917],
#          [-0.66145833]],
#
#         ...,
#
#         [[-0.65364583],
#          [-0.66145833],
#          [-0.66927083],
#          ...,
#          [-0.6640625 ],
#          [-0.67447917],
#          [-0.67708333]],
#
#         [[-0.64583333],
#          [-0.6640625 ],
#          [-0.66927083],
#          ...,
#          [-0.6796875 ],
#          [-0.66666667],
#          [-0.68229167]],
#
#         [[-0.64322917],
#          [-0.65104167],
#          [-0.67708333],
#          ...,
#          [-0.6875    ],
#          [-0.6796875 ],
#          [-0.69270833]]],
#
#
#        ...,
#
#
#        [[[ 0.1484375 ],
#          [ 0.1640625 ],
#          [ 0.15625   ],
#          ...,
#          [-0.2734375 ],
#          [-0.28385417],
#          [-0.32552083]],
#
#         [[ 0.14322917],
#          [ 0.14583333],
#          [ 0.14322917],
#          ...,
#          [-0.23697917],
#          [-0.28125   ],
#          [-0.30729167]],
#
#         [[ 0.140625  ],
#          [ 0.140625  ],
#          [ 0.13802083],
#          ...,
#          [-0.24479167],
#          [-0.15104167],
#          [-0.28645833]],
#
#         ...,
#
#         [[-0.734375  ],
#          [-0.765625  ],
#          [-0.796875  ],
#          ...,
#          [-0.79427083],
#          [-0.8125    ],
#          [-0.82291667]],
#
#         [[-0.76822917],
#          [-0.76302083],
#          [-0.77864583],
#          ...,
#          [-0.8203125 ],
#          [-0.81510417],
#          [-0.84114583]],
#
#         [[-0.80208333],
#          [-0.79947917],
#          [-0.82291667],
#          ...,
#          [-0.83072917],
#          [-0.8359375 ],
#          [-0.83854167]]],
#
#
#        [[[-0.74479167],
#          [-0.70572917],
#          [-0.73958333],
#          ...,
#          [-0.62760417],
#          [-0.65104167],
#          [-0.6328125 ]],
#
#         [[-0.76302083],
#          [-0.72395833],
#          [-0.73958333],
#          ...,
#          [-0.57552083],
#          [-0.69010417],
#          [-0.67447917]],
#
#         [[-0.75260417],
#          [-0.73958333],
#          [-0.7578125 ],
#          ...,
#          [-0.64583333],
#          [-0.671875  ],
#          [-0.68229167]],
#
#         ...,
#
#         [[-0.7265625 ],
#          [-0.78385417],
#          [-0.76302083],
#          ...,
#          [-0.703125  ],
#          [-0.69791667],
#          [-0.73697917]],
#
#         [[-0.75260417],
#          [-0.8046875 ],
#          [-0.7890625 ],
#          ...,
#          [-0.69791667],
#          [-0.5859375 ],
#          [-0.68489583]],
#
#         [[-0.71875   ],
#          [-0.74739583],
#          [-0.78125   ],
#          ...,
#          [-0.6875    ],
#          [-0.515625  ],
#          [-0.625     ]]],
#
#
#        [[[-0.77604167],
#          [-0.77864583],
#          [-0.78385417],
#          ...,
#          [-0.78385417],
#          [-0.79166667],
#          [-0.7890625 ]],
#
#         [[-0.77083333],
#          [-0.77864583],
#          [-0.78645833],
#          ...,
#          [-0.7890625 ],
#          [-0.78645833],
#          [-0.78125   ]],
#
#         [[-0.7734375 ],
#          [-0.78125   ],
#          [-0.7890625 ],
#          ...,
#          [-0.7890625 ],
#          [-0.78385417],
#          [-0.77864583]],
#
#         ...,
#
#         [[-0.73958333],
#          [-0.76302083],
#          [-0.78385417],
#          ...,
#          [-0.78385417],
#          [-0.78385417],
#          [-0.78645833]],
#
#         [[-0.73697917],
#          [-0.7578125 ],
#          [-0.7734375 ],
#          ...,
#          [-0.77864583],
#          [-0.78385417],
#          [-0.78645833]],
#
#         [[-0.72916667],
#          [-0.75520833],
#          [-0.76822917],
#          ...,
#          [-0.7890625 ],
#          [-0.7890625 ],
#          [-0.78125   ]]]])

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# # TASK #5: UNDERSTAND THE THEORY AND INTUITION BEHIND CONVOLUTIONAL NEURAL NETWORKS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #6: BUILD DEEP CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras import datasets, layers, models
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # TASK #7: COMPILE AND TRAIN DEEP CNN MODEL

# %%
# Out:
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 27s 763us/sample - loss: 3.1050 - accuracy: 0.1922 - val_loss: 2.5381 - val_accuracy: 0.3313
# Epoch 2/50
# 34799/34799 [==============================] - 21s 610us/sample - loss: 1.6486 - accuracy: 0.5383 - val_loss: 1.4022 - val_accuracy: 0.5964
# Epoch 3/50
# 34799/34799 [==============================] - 21s 618us/sample - loss: 0.9675 - accuracy: 0.7148 - val_loss: 1.0397 - val_accuracy: 0.6884
# Epoch 4/50
# 34799/34799 [==============================] - 21s 600us/sample - loss: 0.6891 - accuracy: 0.8028 - val_loss: 0.8486 - val_accuracy: 0.7485
# Epoch 5/50
# 34799/34799 [==============================] - 21s 598us/sample - loss: 0.5400 - accuracy: 0.8491 - val_loss: 0.7475 - val_accuracy: 0.7615
# Epoch 6/50
# 34799/34799 [==============================] - 22s 642us/sample - loss: 0.4463 - accuracy: 0.8778 - val_loss: 0.7123 - val_accuracy: 0.7932
# Epoch 7/50
# 34799/34799 [==============================] - 21s 613us/sample - loss: 0.3806 - accuracy: 0.8974 - val_loss: 0.6452 - val_accuracy: 0.8143
# Epoch 8/50
# 34799/34799 [==============================] - 21s 604us/sample - loss: 0.3396 - accuracy: 0.9092 - val_loss: 0.6690 - val_accuracy: 0.8077
# Epoch 9/50
# 34799/34799 [==============================] - 21s 607us/sample - loss: 0.3003 - accuracy: 0.9198 - val_loss: 0.6513 - val_accuracy: 0.8018
# Epoch 10/50
# 34799/34799 [==============================] - 21s 608us/sample - loss: 0.2796 - accuracy: 0.9243 - val_loss: 0.5960 - val_accuracy: 0.8211
# Epoch 11/50
# 34799/34799 [==============================] - 21s 609us/sample - loss: 0.2483 - accuracy: 0.9345 - val_loss: 0.6068 - val_accuracy: 0.8274
# Epoch 12/50
# 34799/34799 [==============================] - 22s 621us/sample - loss: 0.2226 - accuracy: 0.9418 - val_loss: 0.5774 - val_accuracy: 0.8365
# Epoch 13/50
# 34799/34799 [==============================] - 21s 604us/sample - loss: 0.1985 - accuracy: 0.9494 - val_loss: 0.5593 - val_accuracy: 0.8424
# Epoch 14/50
# 34799/34799 [==============================] - 21s 608us/sample - loss: 0.1828 - accuracy: 0.9519 - val_loss: 0.5919 - val_accuracy: 0.8306
# Epoch 15/50
# 34799/34799 [==============================] - 21s 599us/sample - loss: 0.1736 - accuracy: 0.9544 - val_loss: 0.5884 - val_accuracy: 0.8347
# Epoch 16/50
# 34799/34799 [==============================] - 21s 600us/sample - loss: 0.1611 - accuracy: 0.9580 - val_loss: 0.5643 - val_accuracy: 0.8531
# Epoch 17/50
# 34799/34799 [==============================] - 22s 645us/sample - loss: 0.1409 - accuracy: 0.9653 - val_loss: 0.5783 - val_accuracy: 0.8492
# Epoch 18/50
# 34799/34799 [==============================] - 21s 605us/sample - loss: 0.1331 - accuracy: 0.9650 - val_loss: 0.5903 - val_accuracy: 0.8485
# Epoch 19/50
# 34799/34799 [==============================] - 21s 592us/sample - loss: 0.1292 - accuracy: 0.9665 - val_loss: 0.6262 - val_accuracy: 0.8392
# Epoch 20/50
# 34799/34799 [==============================] - 21s 605us/sample - loss: 0.1147 - accuracy: 0.9709 - val_loss: 0.6094 - val_accuracy: 0.8417
# Epoch 21/50
# 34799/34799 [==============================] - 21s 600us/sample - loss: 0.1074 - accuracy: 0.9725 - val_loss: 0.6215 - val_accuracy: 0.8490
# Epoch 22/50
# 34799/34799 [==============================] - 21s 593us/sample - loss: 0.0986 - accuracy: 0.9753 - val_loss: 0.6132 - val_accuracy: 0.8549
# Epoch 23/50
# 34799/34799 [==============================] - 21s 603us/sample - loss: 0.0951 - accuracy: 0.9745 - val_loss: 0.6403 - val_accuracy: 0.8442
# Epoch 24/50
# 34799/34799 [==============================] - 22s 629us/sample - loss: 0.0880 - accuracy: 0.9772 - val_loss: 0.6116 - val_accuracy: 0.8592
# Epoch 25/50
# 34799/34799 [==============================] - 21s 613us/sample - loss: 0.0849 - accuracy: 0.9770 - val_loss: 0.6597 - val_accuracy: 0.8537
# Epoch 26/50
# 34799/34799 [==============================] - 21s 614us/sample - loss: 0.0785 - accuracy: 0.9791 - val_loss: 0.6688 - val_accuracy: 0.8399
# Epoch 27/50
# 34799/34799 [==============================] - 21s 618us/sample - loss: 0.0688 - accuracy: 0.9828 - val_loss: 0.6471 - val_accuracy: 0.8537
# Epoch 28/50
# 34799/34799 [==============================] - 21s 614us/sample - loss: 0.0665 - accuracy: 0.9829 - val_loss: 0.6291 - val_accuracy: 0.8621
# Epoch 29/50
# 34799/34799 [==============================] - 22s 630us/sample - loss: 0.0606 - accuracy: 0.9841 - val_loss: 0.6253 - val_accuracy: 0.8546
# Epoch 30/50
# 34799/34799 [==============================] - 21s 594us/sample - loss: 0.0596 - accuracy: 0.9847 - val_loss: 0.6788 - val_accuracy: 0.8574
# Epoch 31/50
# 34799/34799 [==============================] - 20s 589us/sample - loss: 0.0544 - accuracy: 0.9859 - val_loss: 0.6637 - val_accuracy: 0.8553
# Epoch 32/50
# 34799/34799 [==============================] - 20s 582us/sample - loss: 0.0504 - accuracy: 0.9873 - val_loss: 0.6535 - val_accuracy: 0.8599
# Epoch 33/50
# 34799/34799 [==============================] - 21s 591us/sample - loss: 0.0471 - accuracy: 0.9876 - val_loss: 0.6826 - val_accuracy: 0.8599
# Epoch 34/50
# 34799/34799 [==============================] - 20s 581us/sample - loss: 0.0424 - accuracy: 0.9903 - val_loss: 0.7182 - val_accuracy: 0.8544
# Epoch 35/50
# 34799/34799 [==============================] - 21s 613us/sample - loss: 0.0431 - accuracy: 0.9891 - val_loss: 0.6909 - val_accuracy: 0.8642
# Epoch 36/50
# 34799/34799 [==============================] - 20s 586us/sample - loss: 0.0425 - accuracy: 0.9886 - val_loss: 0.7335 - val_accuracy: 0.8621
# Epoch 37/50
# 34799/34799 [==============================] - 21s 601us/sample - loss: 0.0401 - accuracy: 0.9892 - val_loss: 0.7297 - val_accuracy: 0.8519
# Epoch 38/50
# 34799/34799 [==============================] - 21s 607us/sample - loss: 0.0332 - accuracy: 0.9917 - val_loss: 0.7344 - val_accuracy: 0.8630
# Epoch 39/50
# 34799/34799 [==============================] - 21s 601us/sample - loss: 0.0329 - accuracy: 0.9921 - val_loss: 0.7679 - val_accuracy: 0.8601
# Epoch 40/50
# 34799/34799 [==============================] - 21s 609us/sample - loss: 0.0360 - accuracy: 0.9904 - val_loss: 0.7015 - val_accuracy: 0.8671
# Epoch 41/50
# 34799/34799 [==============================] - 22s 619us/sample - loss: 0.0293 - accuracy: 0.9927 - val_loss: 0.7163 - val_accuracy: 0.8671
# Epoch 42/50
# 34799/34799 [==============================] - 21s 608us/sample - loss: 0.0280 - accuracy: 0.9931 - val_loss: 0.7518 - val_accuracy: 0.8673
# Epoch 43/50
# 34799/34799 [==============================] - 21s 608us/sample - loss: 0.0275 - accuracy: 0.9933 - val_loss: 0.7005 - val_accuracy: 0.8723
# Epoch 44/50
# 34799/34799 [==============================] - 21s 603us/sample - loss: 0.0293 - accuracy: 0.9925 - val_loss: 0.7265 - val_accuracy: 0.8751
# Epoch 45/50
# 34799/34799 [==============================] - 21s 614us/sample - loss: 0.0341 - accuracy: 0.9902 - val_loss: 0.8377 - val_accuracy: 0.8626
# Epoch 46/50
# 34799/34799 [==============================] - 21s 608us/sample - loss: 0.0299 - accuracy: 0.9916 - val_loss: 0.6990 - val_accuracy: 0.8689
# Epoch 47/50
# 34799/34799 [==============================] - 21s 597us/sample - loss: 0.0240 - accuracy: 0.9936 - val_loss: 0.6903 - val_accuracy: 0.8803
# Epoch 48/50
# 34799/34799 [==============================] - 21s 596us/sample - loss: 0.0215 - accuracy: 0.9949 - val_loss: 0.8040 - val_accuracy: 0.8592
# Epoch 49/50
# 34799/34799 [==============================] - 21s 600us/sample - loss: 0.0206 - accuracy: 0.9947 - val_loss: 0.7934 - val_accuracy: 0.8585
# Epoch 50/50
# 34799/34799 [==============================] - 21s 606us/sample - loss: 0.0264 - accuracy: 0.9927 - val_loss: 0.8059 - val_accuracy: 0.8721

# %% [markdown]
# # TASK #8: ASSESS TRAINED CNN MODEL PERFORMANCE

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 12630/12630 [==============================] - 4s 347us/sample - loss: 1.2523 - accuracy: 0.8644
# Test Accuracy: 0.8643705248832703

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %% [markdown]
# # CONGRATULATIONS ON FINISHING THE PROJECT!
